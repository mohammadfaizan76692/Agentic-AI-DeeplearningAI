# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"Write the detailed essay on the topic  : {topic}"

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f""" You are Essay Critique and you have to give the feedback on the given,
    the feedback should be critical but constructive and It should address issues such as structure, clarity, 
    strength of argument, and writing style.
    essay:{draft}
    """ 

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""Your are best essay Writer your task to improve initial eassy drafts with the feedback 
    to re-write the eassy by considering the feedback given .
    Initial Essay Draft: {original_draft}
    Feedback: {reflection}
    """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: The Regulation of Social Media Platforms: A Necessary Evolution or an Overreach of Power?
#
# Introduction:
# Social media platforms have fundamentally reshaped the way people communicate, share information, and form communities. With over four billion users globally, social media has become an indispensable part of modern life. However, the omnipresence and power wielded by these platforms have raised significant concerns regarding privacy, misinformation, and influence over democratic processes. These concerns have sparked a global debate on whether social media platforms should be regulated by the government. This essay explores the potential benefits and drawbacks of such regulation, ultimately arguing that while some level of regulation is necessary, it must be carefully balanced to avoid stifling innovation and infringing on free speech.
#
# The Case for Regulation:
#
# 1. **Prevention of Harmful Content**: One of the foremost arguments for government regulation is the need to prevent the spread of harmful content. Social media is rife with hate speech, bullying, and explicit content that can lead to real-world violence and psychological harm. By imposing regulations, governments can establish clearer guidelines on what constitutes acceptable content, thus protecting users from harm.
#
# 2. **Combating Misinformation**: Social media platforms are powerful tools for the dissemination of information; however, they are equally potent in spreading misinformation and fake news. Unchecked, false information can influence public opinion, electoral processes, and even incite violence. Government regulation could ensure that platforms take responsibility for fact-checking information and thwart the spread of false narratives.
#
# 3. **Privacy Protection**: Social media platforms gather immense amounts of personal data, often with minimal transparency regarding its usage. Regulations could mandate better data protection policies, giving users control over their information and ensuring that companies are held accountable for data breaches and misuse.
#
# 4. **Accountability and Transparency**: Social media companies wield significant power with minimal accountability. Regulation can enforce greater transparency in how platforms operate, make decisions about content moderation, and manage algorithms. This would help ensure that these platforms act in the public's interest rather than solely pursuing profit.
#
# The Case Against Regulation:
#
# 1. **Threat to Free Speech**: One of the primary concerns with government regulation of social media is the potential threat to free speech. Excessive control could lead to censorship, stifling dissent and silencing minority viewpoints. The risk of governments using regulatory power to suppress opposition makes it essential to carefully delineate the boundaries of regulation.
#
# 2. **Stifling Innovation**: Social media has thrived in part due to the freedom to innovate rapidly. Imposing heavy regulations could hamper this dynamism, making platforms less adaptable and slowing the pace of technological advancement. This could also discourage new entrants in the market, leading to reduced competition and consumer choice.
#
# 3. **Global Challenges**: Social media is a global phenomenon, and regulations established by one country's government may not be applicable or appropriate in another. This can create compliance challenges for multinational platforms and lead to fragmented user experiences across regions.
#
# 4. **Implementation Difficulties**: Crafting effective regulations for social media is fraught with challenges. The dynamic and ever-evolving nature of social media technologies makes it difficult for legislation to keep pace. Moreover, determining the specifics of what constitutes harmful content or misinformation can be highly subjective, complicating enforcement.
#
# Conclusion:
#
# As social media becomes increasingly embedded in daily life, the call for its regulation is likely to grow louder. While the potential benefits of regulation—such as protecting users from harm, curbing misinformation, and ensuring privacy—are significant, the risks associated with overregulation are equally substantial. Rather than blanket governmental overreach, a more nuanced approach involving collaboration between governments, social media companies, and civil society is essential. This collaborative effort can ensure that regulation is responsive, adaptive, and respects fundamental rights such as free speech while safeguarding public interest. Ultimately, the goal should be to create a balanced framework that harnesses the transformative power of social media for good while minimizing its potential for harm.
#
# 🧠 Feedback:
#
# Here’s a critical yet constructive appraisal of your essay, organized around its structure, clarity, argumentative strength, and style:
#
# 1. Structure
#   • Introduction
#     – Strengths: You establish the topic’s global importance and outline the stakes (privacy, misinformation, democracy).
#     – Areas to improve: Your thesis (“some level of regulation is necessary…”) could be more assertive and specific. Right now it reads as balanced, but doesn’t preview how you’ll weigh benefits against risks. Consider a one-sentence roadmap that signals your ultimate stance and how you’ll get there.
#   • Body Paragraphs
#     – Strengths: You adopt a clear pro-con framework, which helps the reader follow both sides.
#     – Areas to improve:
#       • Transitioning: The numbered lists read more like an outline than a fluid essay. Turn each point into a fully developed paragraph with a topic sentence, concrete evidence (e.g., recent studies, real-world examples), and analysis of how that evidence supports your claim.
#       • Balance and depth: Some “pro” points (e.g., combating misinformation) feel under-developed. You mention “fact-checking,” but don’t discuss who bears the cost or how you prevent fact-checker bias. Likewise, the “con” section could use specific cases of regulatory overreach to illustrate the threat to free speech.
#   • Conclusion
#     – Strengths: You reinforce the need for a nuanced approach and collaborative model.
#     – Areas to improve: Rather than restating earlier points, push further by suggesting concrete next steps—a framework for multi-stakeholder governance or criteria for measuring regulatory success. That will leave the reader with a clear vision.
#
# 2. Clarity
#   • Your prose is generally clear and accessible, but it occasionally lapses into abstractions (e.g., “stifling innovation,” “harmful content”). Whenever you introduce a term like “harmful,” give a quick definition or an example (child exploitation, graphic violence) to anchor your argument.
#   • Watch for vague qualifiers (“some level of regulation,” “carefully balanced”). Be precise about what “some” and “careful” entail to strengthen your credibility.
#
# 3. Strength of Argument
#   • Evidence and Examples: Right now your claims rest largely on general assertions. Bolster them with data (statistics on hate-speech incidents), landmark cases (e.g., Germany’s NetzDG law), or expert opinions.
#   • Counterargument Engagement: You acknowledge free-speech risks, but you don’t fully grapple with them. To deepen your analysis, ask: How do we ensure regulation doesn’t slip into political censorship? What guardrails can be built into law?
#   • Nuance: Social media companies differ drastically—Facebook’s challenges aren’t identical to TikTok’s. A more tailored discussion of how regulation could adapt to different platform models would demonstrate sophistication.
#
# 4. Writing Style
#   • Tone: Your formal tone is appropriate, but it leans toward the passive voice (“regulation is wielded,” “information can be influenced”). Switch to active constructions (“Governments wield regulation to…”).
#   • Variety: Sentence structures are fairly uniform. Introduce some shorter, punchier sentences amid longer ones to improve rhythm and keep the reader’s attention.
#   • Vocabulary: You repeat key terms (regulation, innovation, free speech) in close succession. Use synonyms or rephrase to avoid monotony (e.g., “oversight” for regulation, “dissenting voices” for free speech).
#
# 5. Overall Recommendations
#   – Strengthen your thesis by previewing key arguments and indicating your ultimate evaluation.
#   – Flesh out each numbered point into standalone paragraphs with topic sentences, evidence, and analysis.
#   – Integrate concrete examples—laws, incidents, statistics—to ground your abstract claims.
#   – Address counterarguments more robustly by offering specific safeguards or trade-off mechanisms.
#   – Vary sentence length and adopt active voice to keep the prose engaging.
#
# By tightening your thesis, enriching your evidence, and polishing your prose, you’ll transform this solid outline into a compelling, nuanced essay on one of the most pressing policy debates of our time.
# ✍️ Revised:
#
# Title: The Regulation of Social Media Platforms: Balancing Innovation and Accountability
#
# Introduction:
# Social media platforms have fundamentally reshaped communication, information sharing, and community building on a global scale, with over four billion users worldwide. They have become indispensable in modern life, yet their ubiquity and influence have raised significant concerns about privacy, misinformation, and their impact on democratic processes. This has sparked an intense debate on whether social media platforms require government regulation. This essay argues that while regulation is necessary to address potential harms, it must be carefully formulated to avoid stifling innovation and infringing on free speech. A balanced, multi-stakeholder approach can harness social media's transformative power while minimizing its potential for harm.
#
# The Case for Regulation:
#
# Preventing Harmful Content: The proliferation of hate speech, bullying, and explicit content on social media can lead to real-world violence and psychological harm. Government regulation can establish guidelines on acceptable content. For instance, Germany’s Network Enforcement Act (NetzDG) mandates swift removal of illegal content, exemplifying how regulation can protect users from harm while holding platforms accountable.
#
# Combating Misinformation: Social media is potent for information spread, but also for misinformation. False information can skew public opinion and disrupt electoral processes. Regulation could require platforms to implement robust fact-checking systems, sharing the responsibility and costs of maintaining information integrity. This raises questions about bias in fact-checking, necessitating transparent and diverse panels to ensure impartiality.
#
# Privacy Protection: The vast data collection by social media platforms often lacks transparency. Regulations should mandate stringent data protection, emphasizing user control over information. The European Union’s General Data Protection Regulation (GDPR) serves as a benchmark in holding companies accountable, illustrating the positive impact of well-formulated privacy laws.
#
# Accountability and Transparency: Social media companies operate with immense power but minimal accountability. Regulation can enforce transparency in content moderation and algorithm management, ensuring platforms align with public interest over profit. This could involve mandatory reporting on decision-making processes and the criteria used for content moderation.
#
# The Case Against Regulation:
#
# Threat to Free Speech: Government regulation risks infringing on free speech and may result in censorship, restricting dissent and minority viewpoints. Regulatory overreach by undesirable political regimes could suppress opposition. To counter, regulations should include explicit safeguards, ensuring that actions taken are proportionate and focused on clearly defined harmful activities.
#
# Stifling Innovation: The rapid innovation of social media partly stems from a lack of restrictive regulations. Over-regulation could stifle this innovation and discourage new market entrants. Policymakers must craft adaptable regulations, encouraging innovation while introducing minimum necessary standards for user protection.
#
# Global Challenges: Social media's global nature means regulations suitable for one country may not fit another, leading to compliance challenges for multinational platforms. Fragmented regulations could create uneven user experiences. International cooperation could establish baseline regulatory principles, facilitating a more uniform global approach.
#
# Implementation Difficulties: Crafting effective regulations is challenging due to the evolving nature of social media. Definitions of harmful content and misinformation can be subjective, complicating enforcement. Regular consultation with experts, platform representatives, and civil society can ensure legislation evolves alongside technologies.
#
# Conclusion:
# As social media continues to integrate into everyday life, the demand for regulation will grow. While regulation's potential benefits—protecting users, curbing misinformation, ensuring privacy—are significant, over-regulation risks are equally substantial. A nuanced, collaborative effort between governments, companies, and civil entities is crucial for responsive regulation. This framework should adapt to different platform models and prioritize free speech while safeguarding public interest. The ultimate aim is a balanced approach that captures the potential of social media for good and minimizes its capacity for harm, establishing a framework for effective, adaptable, and fair governance.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Regulation of Social Media Platforms: A Necessary Evolution or an Overreach of Power?
#
# Introduction:
# Social media platforms have fundamentally reshaped the way people communicate, share information, and form communities. With over four billion users globally, social media has become an indispensable part of modern life. However, the omnipresence and power wielded by these platforms have raised significant concerns regarding privacy, misinformation, and influence over democratic processes. These concerns have sparked a global debate on whether social media platforms should be regulated by the government. This essay explores the potential benefits and drawbacks of such regulation, ultimately arguing that while some level of regulation is necessary, it must be carefully balanced to avoid stifling innovation and infringing on free speech.
#
# The Case for Regulation:
#
# 1. **Prevention of Harmful Content**: One of the foremost arguments for government regulation is the need to prevent the spread of harmful content. Social media is rife with hate speech, bullying, and explicit content that can lead to real-world violence and psychological harm. By imposing regulations, governments can establish clearer guidelines on what constitutes acceptable content, thus protecting users from harm.
#
# 2. **Combating Misinformation**: Social media platforms are powerful tools for the dissemination of information; however, they are equally potent in spreading misinformation and fake news. Unchecked, false information can influence public opinion, electoral processes, and even incite violence. Government regulation could ensure that platforms take responsibility for fact-checking information and thwart the spread of false narratives.
#
# 3. **Privacy Protection**: Social media platforms gather immense amounts of personal data, often with minimal transparency regarding its usage. Regulations could mandate better data protection policies, giving users control over their information and ensuring that companies are held accountable for data breaches and misuse.
#
# 4. **Accountability and Transparency**: Social media companies wield significant power with minimal accountability. Regulation can enforce greater transparency in how platforms operate, make decisions about content moderation, and manage algorithms. This would help ensure that these platforms act in the public's interest rather than solely pursuing profit.
#
# The Case Against Regulation:
#
# 1. **Threat to Free Speech**: One of the primary concerns with government regulation of social media is the potential threat to free speech. Excessive control could lead to censorship, stifling dissent and silencing minority viewpoints. The risk of governments using regulatory power to suppress opposition makes it essential to carefully delineate the boundaries of regulation.
#
# 2. **Stifling Innovation**: Social media has thrived in part due to the freedom to innovate rapidly. Imposing heavy regulations could hamper this dynamism, making platforms less adaptable and slowing the pace of technological advancement. This could also discourage new entrants in the market, leading to reduced competition and consumer choice.
#
# 3. **Global Challenges**: Social media is a global phenomenon, and regulations established by one country's government may not be applicable or appropriate in another. This can create compliance challenges for multinational platforms and lead to fragmented user experiences across regions.
#
# 4. **Implementation Difficulties**: Crafting effective regulations for social media is fraught with challenges. The dynamic and ever-evolving nature of social media technologies makes it difficult for legislation to keep pace. Moreover, determining the specifics of what constitutes harmful content or misinformation can be highly subjective, complicating enforcement.
#
# Conclusion:
#
# As social media becomes increasingly embedded in daily life, the call for its regulation is likely to grow louder. While the potential benefits of regulation—such as protecting users from harm, curbing misinformation, and ensuring privacy—are significant, the risks associated with overregulation are equally substantial. Rather than blanket governmental overreach, a more nuanced approach involving collaboration between governments, social media companies, and civil society is essential. This collaborative effort can ensure that regulation is responsive, adaptive, and respects fundamental rights such as free speech while safeguarding public interest. Ultimately, the goal should be to create a balanced framework that harnesses the transformative power of social media for good while minimizing its potential for harm.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Here’s a critical yet constructive appraisal of your essay, organized around its structure, clarity, argumentative strength, and style:
#
# 1. Structure
#   • Introduction
#     – Strengths: You establish the topic’s global importance and outline the stakes (privacy, misinformation, democracy).
#     – Areas to improve: Your thesis (“some level of regulation is necessary…”) could be more assertive and specific. Right now it reads as balanced, but doesn’t preview how you’ll weigh benefits against risks. Consider a one-sentence roadmap that signals your ultimate stance and how you’ll get there.
#   • Body Paragraphs
#     – Strengths: You adopt a clear pro-con framework, which helps the reader follow both sides.
#     – Areas to improve:
#       • Transitioning: The numbered lists read more like an outline than a fluid essay. Turn each point into a fully developed paragraph with a topic sentence, concrete evidence (e.g., recent studies, real-world examples), and analysis of how that evidence supports your claim.
#       • Balance and depth: Some “pro” points (e.g., combating misinformation) feel under-developed. You mention “fact-checking,” but don’t discuss who bears the cost or how you prevent fact-checker bias. Likewise, the “con” section could use specific cases of regulatory overreach to illustrate the threat to free speech.
#   • Conclusion
#     – Strengths: You reinforce the need for a nuanced approach and collaborative model.
#     – Areas to improve: Rather than restating earlier points, push further by suggesting concrete next steps—a framework for multi-stakeholder governance or criteria for measuring regulatory success. That will leave the reader with a clear vision.
#
# 2. Clarity
#   • Your prose is generally clear and accessible, but it occasionally lapses into abstractions (e.g., “stifling innovation,” “harmful content”). Whenever you introduce a term like “harmful,” give a quick definition or an example (child exploitation, graphic violence) to anchor your argument.
#   • Watch for vague qualifiers (“some level of regulation,” “carefully balanced”). Be precise about what “some” and “careful” entail to strengthen your credibility.
#
# 3. Strength of Argument
#   • Evidence and Examples: Right now your claims rest largely on general assertions. Bolster them with data (statistics on hate-speech incidents), landmark cases (e.g., Germany’s NetzDG law), or expert opinions.
#   • Counterargument Engagement: You acknowledge free-speech risks, but you don’t fully grapple with them. To deepen your analysis, ask: How do we ensure regulation doesn’t slip into political censorship? What guardrails can be built into law?
#   • Nuance: Social media companies differ drastically—Facebook’s challenges aren’t identical to TikTok’s. A more tailored discussion of how regulation could adapt to different platform models would demonstrate sophistication.
#
# 4. Writing Style
#   • Tone: Your formal tone is appropriate, but it leans toward the passive voice (“regulation is wielded,” “information can be influenced”). Switch to active constructions (“Governments wield regulation to…”).
#   • Variety: Sentence structures are fairly uniform. Introduce some shorter, punchier sentences amid longer ones to improve rhythm and keep the reader’s attention.
#   • Vocabulary: You repeat key terms (regulation, innovation, free speech) in close succession. Use synonyms or rephrase to avoid monotony (e.g., “oversight” for regulation, “dissenting voices” for free speech).
#
# 5. Overall Recommendations
#   – Strengthen your thesis by previewing key arguments and indicating your ultimate evaluation.
#   – Flesh out each numbered point into standalone paragraphs with topic sentences, evidence, and analysis.
#   – Integrate concrete examples—laws, incidents, statistics—to ground your abstract claims.
#   – Address counterarguments more robustly by offering specific safeguards or trade-off mechanisms.
#   – Vary sentence length and adopt active voice to keep the prose engaging.
#
# By tightening your thesis, enriching your evidence, and polishing your prose, you’ll transform this solid outline into a compelling, nuanced essay on one of the most pressing policy debates of our time.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Regulation of Social Media Platforms: Balancing Innovation and Accountability
#
# Introduction:
# Social media platforms have fundamentally reshaped communication, information sharing, and community building on a global scale, with over four billion users worldwide. They have become indispensable in modern life, yet their ubiquity and influence have raised significant concerns about privacy, misinformation, and their impact on democratic processes. This has sparked an intense debate on whether social media platforms require government regulation. This essay argues that while regulation is necessary to address potential harms, it must be carefully formulated to avoid stifling innovation and infringing on free speech. A balanced, multi-stakeholder approach can harness social media's transformative power while minimizing its potential for harm.
#
# The Case for Regulation:
#
# Preventing Harmful Content: The proliferation of hate speech, bullying, and explicit content on social media can lead to real-world violence and psychological harm. Government regulation can establish guidelines on acceptable content. For instance, Germany’s Network Enforcement Act (NetzDG) mandates swift removal of illegal content, exemplifying how regulation can protect users from harm while holding platforms accountable.
#
# Combating Misinformation: Social media is potent for information spread, but also for misinformation. False information can skew public opinion and disrupt electoral processes. Regulation could require platforms to implement robust fact-checking systems, sharing the responsibility and costs of maintaining information integrity. This raises questions about bias in fact-checking, necessitating transparent and diverse panels to ensure impartiality.
#
# Privacy Protection: The vast data collection by social media platforms often lacks transparency. Regulations should mandate stringent data protection, emphasizing user control over information. The European Union’s General Data Protection Regulation (GDPR) serves as a benchmark in holding companies accountable, illustrating the positive impact of well-formulated privacy laws.
#
# Accountability and Transparency: Social media companies operate with immense power but minimal accountability. Regulation can enforce transparency in content moderation and algorithm management, ensuring platforms align with public interest over profit. This could involve mandatory reporting on decision-making processes and the criteria used for content moderation.
#
# The Case Against Regulation:
#
# Threat to Free Speech: Government regulation risks infringing on free speech and may result in censorship, restricting dissent and minority viewpoints. Regulatory overreach by undesirable political regimes could suppress opposition. To counter, regulations should include explicit safeguards, ensuring that actions taken are proportionate and focused on clearly defined harmful activities.
#
# Stifling Innovation: The rapid innovation of social media partly stems from a lack of restrictive regulations. Over-regulation could stifle this innovation and discourage new market entrants. Policymakers must craft adaptable regulations, encouraging innovation while introducing minimum necessary standards for user protection.
#
# Global Challenges: Social media's global nature means regulations suitable for one country may not fit another, leading to compliance challenges for multinational platforms. Fragmented regulations could create uneven user experiences. International cooperation could establish baseline regulatory principles, facilitating a more uniform global approach.
#
# Implementation Difficulties: Crafting effective regulations is challenging due to the evolving nature of social media. Definitions of harmful content and misinformation can be subjective, complicating enforcement. Regular consultation with experts, platform representatives, and civil society can ensure legislation evolves alongside technologies.
#
# Conclusion:
# As social media continues to integrate into everyday life, the demand for regulation will grow. While regulation's potential benefits—protecting users, curbing misinformation, ensuring privacy—are significant, over-regulation risks are equally substantial. A nuanced, collaborative effort between governments, companies, and civil entities is crucial for responsive regulation. This framework should adapt to different platform models and prioritize free speech while safeguarding public interest. The ultimate aim is a balanced approach that captures the potential of social media for good and minimizes its capacity for harm, establishing a framework for effective, adaptable, and fair governance.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
